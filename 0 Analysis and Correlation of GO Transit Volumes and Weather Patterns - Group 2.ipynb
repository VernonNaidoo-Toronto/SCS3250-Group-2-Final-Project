# %% [markdown]
# # Analysis and Correlation of GO Transit Volumes and Weather Patterns

# %% [markdown]
# ## Introduction

# %% [markdown]
# *   Overview
# *   Goals
# *   Hypotheses

# %% [markdown]
# ## Part 1: Data Preparation and Cleaning

# %% [markdown]
# * Load transit data files; merge; reshape; identify outliers -> transit.csv
# * Load weather data files; merge with transit -> weather.csv
# * Merge transit and weather -> Final Data.csv
# * [DATA PREPARATION AND CLEANING (link to Jupyter notebook)](https://drive.google.com/open?id=1bi8J1WCP75z4DlidCe-_YAnE3A5tGBCO)

# %% [markdown]
# ## Phase 2: Analysis

# %% [markdown]
# * Correlation
# * Autocorrelation
# * [ANALYSIS (link to Jupyter notebook)](https://drive.google.com/open?id=1UMslFIfmyRcMyIpzarod1sGozdIa-YR1)

# %% [markdown]
# ## Phase 3: Machine Learning

# %% [markdown]
# * Classification (kNN)
# * Regression
# * [MACHINE LEARNING (link to Jupyter notebook)](https://colab.research.google.com/drive/1iQo2b1zIshHTuNc167PriEb1LXHt_ZEN)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Overall thoughts
# * Successes, failures, dead ends
# * Ideas for further study
